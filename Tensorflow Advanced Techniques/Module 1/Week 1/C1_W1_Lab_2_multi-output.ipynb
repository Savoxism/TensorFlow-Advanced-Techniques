# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 263.0630 - y1_output_loss: 124.3365 - y2_output_loss: 137.9669 - y1_output_root_mean_squared_error: 11.1893 - y2_output_root_mean_squared_error: 11.7415 - val_loss: 212.1137 - val_y1_output_loss: 49.8998 - val_y2_output_loss: 156.5364 - val_y1_output_root_mean_squared_error: 7.1955 - val_y2_output_root_mean_squared_error: 12.6625
# Epoch 2/500
# 614/614 [==============================] - 0s 167us/sample - loss: 34.8237 - y1_output_loss: 13.2887 - y2_output_loss: 21.3411 - y1_output_root_mean_squared_error: 3.6526 - y2_output_root_mean_squared_error: 4.6349 - val_loss: 30.9562 - val_y1_output_loss: 13.4845 - val_y2_output_loss: 16.4670 - val_y1_output_root_mean_squared_error: 3.7339 - val_y2_output_root_mean_squared_error: 4.1248
# Epoch 3/500
# 614/614 [==============================] - 0s 163us/sample - loss: 31.5613 - y1_output_loss: 11.5767 - y2_output_loss: 19.8543 - y1_output_root_mean_squared_error: 3.4075 - y2_output_root_mean_squared_error: 4.4666 - val_loss: 25.5905 - val_y1_output_loss: 9.9161 - val_y2_output_loss: 14.8182 - val_y1_output_root_mean_squared_error: 3.2041 - val_y2_output_root_mean_squared_error: 3.9146
# Epoch 4/500
# 614/614 [==============================] - 0s 165us/sample - loss: 23.0052 - y1_output_loss: 9.2606 - y2_output_loss: 13.5963 - y1_output_root_mean_squared_error: 3.0547 - y2_output_root_mean_squared_error: 3.6978 - val_loss: 33.6729 - val_y1_output_loss: 12.1976 - val_y2_output_loss: 20.6435 - val_y1_output_root_mean_squared_error: 3.5448 - val_y2_output_root_mean_squared_error: 4.5943
# Epoch 5/500
# 614/614 [==============================] - 0s 149us/sample - loss: 26.7872 - y1_output_loss: 9.4980 - y2_output_loss: 17.8297 - y1_output_root_mean_squared_error: 3.0368 - y2_output_root_mean_squared_error: 4.1911 - val_loss: 105.6212 - val_y1_output_loss: 30.8429 - val_y2_output_loss: 72.3072 - val_y1_output_root_mean_squared_error: 5.6311 - val_y2_output_root_mean_squared_error: 8.5972
# Epoch 6/500
# 614/614 [==============================] - 0s 156us/sample - loss: 24.9858 - y1_output_loss: 9.1896 - y2_output_loss: 15.5910 - y1_output_root_mean_squared_error: 3.0425 - y2_output_root_mean_squared_error: 3.9660 - val_loss: 22.4113 - val_y1_output_loss: 10.2001 - val_y2_output_loss: 11.5543 - val_y1_output_root_mean_squared_error: 3.2430 - val_y2_output_root_mean_squared_error: 3.4488
# Epoch 7/500
# 614/614 [==============================] - 0s 168us/sample - loss: 21.8198 - y1_output_loss: 8.3788 - y2_output_loss: 13.2400 - y1_output_root_mean_squared_error: 2.9080 - y2_output_root_mean_squared_error: 3.6556 - val_loss: 18.8558 - val_y1_output_loss: 8.4383 - val_y2_output_loss: 9.7404 - val_y1_output_root_mean_squared_error: 2.9580 - val_y2_output_root_mean_squared_error: 3.1790
# Epoch 8/500
# 614/614 [==============================] - 0s 169us/sample - loss: 19.6234 - y1_output_loss: 7.6787 - y2_output_loss: 11.7972 - y1_output_root_mean_squared_error: 2.7805 - y2_output_root_mean_squared_error: 3.4485 - val_loss: 20.1711 - val_y1_output_loss: 7.6775 - val_y2_output_loss: 11.9527 - val_y1_output_root_mean_squared_error: 2.8125 - val_y2_output_root_mean_squared_error: 3.5016
# Epoch 9/500
# 614/614 [==============================] - 0s 158us/sample - loss: 24.5231 - y1_output_loss: 9.1408 - y2_output_loss: 15.5695 - y1_output_root_mean_squared_error: 3.0221 - y2_output_root_mean_squared_error: 3.9230 - val_loss: 23.8882 - val_y1_output_loss: 7.7540 - val_y2_output_loss: 15.5031 - val_y1_output_root_mean_squared_error: 2.8291 - val_y2_output_root_mean_squared_error: 3.9856
# Epoch 10/500
# 614/614 [==============================] - 0s 144us/sample - loss: 19.8445 - y1_output_loss: 7.7942 - y2_output_loss: 11.9760 - y1_output_root_mean_squared_error: 2.7979 - y2_output_root_mean_squared_error: 3.4664 - val_loss: 19.6102 - val_y1_output_loss: 8.0463 - val_y2_output_loss: 11.0533 - val_y1_output_root_mean_squared_error: 2.8751 - val_y2_output_root_mean_squared_error: 3.3681
# Epoch 11/500
# 614/614 [==============================] - 0s 157us/sample - loss: 19.3392 - y1_output_loss: 7.6902 - y2_output_loss: 11.4994 - y1_output_root_mean_squared_error: 2.7850 - y2_output_root_mean_squared_error: 3.4034 - val_loss: 18.0051 - val_y1_output_loss: 8.1124 - val_y2_output_loss: 9.3274 - val_y1_output_root_mean_squared_error: 2.8924 - val_y2_output_root_mean_squared_error: 3.1047
# Epoch 12/500
# 614/614 [==============================] - 0s 147us/sample - loss: 17.3346 - y1_output_loss: 7.2017 - y2_output_loss: 10.0120 - y1_output_root_mean_squared_error: 2.6925 - y2_output_root_mean_squared_error: 3.1757 - val_loss: 16.1962 - val_y1_output_loss: 7.1276 - val_y2_output_loss: 8.4798 - val_y1_output_root_mean_squared_error: 2.7187 - val_y2_output_root_mean_squared_error: 2.9673
# Epoch 13/500
# 614/614 [==============================] - 0s 160us/sample - loss: 19.8933 - y1_output_loss: 7.3473 - y2_output_loss: 12.4210 - y1_output_root_mean_squared_error: 2.7160 - y2_output_root_mean_squared_error: 3.5379 - val_loss: 15.9872 - val_y1_output_loss: 6.8898 - val_y2_output_loss: 8.5706 - val_y1_output_root_mean_squared_error: 2.6649 - val_y2_output_root_mean_squared_error: 2.9809
# Epoch 14/500
# 614/614 [==============================] - 0s 159us/sample - loss: 17.3221 - y1_output_loss: 7.0278 - y2_output_loss: 10.3606 - y1_output_root_mean_squared_error: 2.6505 - y2_output_root_mean_squared_error: 3.2089 - val_loss: 30.6784 - val_y1_output_loss: 11.6042 - val_y2_output_loss: 18.3889 - val_y1_output_root_mean_squared_error: 3.4460 - val_y2_output_root_mean_squared_error: 4.3363
# Epoch 15/500
# 614/614 [==============================] - 0s 150us/sample - loss: 18.0721 - y1_output_loss: 7.0479 - y2_output_loss: 10.9262 - y1_output_root_mean_squared_error: 2.6652 - y2_output_root_mean_squared_error: 3.3119 - val_loss: 36.6446 - val_y1_output_loss: 10.9163 - val_y2_output_loss: 25.0563 - val_y1_output_root_mean_squared_error: 3.3394 - val_y2_output_root_mean_squared_error: 5.0491
# Epoch 16/500
# 614/614 [==============================] - 0s 148us/sample - loss: 17.8813 - y1_output_loss: 6.6171 - y2_output_loss: 11.2302 - y1_output_root_mean_squared_error: 2.5812 - y2_output_root_mean_squared_error: 3.3494 - val_loss: 24.7844 - val_y1_output_loss: 8.4385 - val_y2_output_loss: 15.7205 - val_y1_output_root_mean_squared_error: 2.9458 - val_y2_output_root_mean_squared_error: 4.0133
# Epoch 17/500
# 614/614 [==============================] - 0s 155us/sample - loss: 15.7621 - y1_output_loss: 6.1042 - y2_output_loss: 9.7603 - y1_output_root_mean_squared_error: 2.4665 - y2_output_root_mean_squared_error: 3.1110 - val_loss: 20.1296 - val_y1_output_loss: 7.9869 - val_y2_output_loss: 11.4503 - val_y1_output_root_mean_squared_error: 2.8770 - val_y2_output_root_mean_squared_error: 3.4428
# Epoch 18/500
# 614/614 [==============================] - 0s 142us/sample - loss: 16.5497 - y1_output_loss: 6.1981 - y2_output_loss: 10.4240 - y1_output_root_mean_squared_error: 2.4878 - y2_output_root_mean_squared_error: 3.2188 - val_loss: 16.0282 - val_y1_output_loss: 7.0565 - val_y2_output_loss: 8.7898 - val_y1_output_root_mean_squared_error: 2.6689 - val_y2_output_root_mean_squared_error: 2.9841
# Epoch 19/500
# 614/614 [==============================] - 0s 155us/sample - loss: 15.1602 - y1_output_loss: 5.7222 - y2_output_loss: 9.6571 - y1_output_root_mean_squared_error: 2.3632 - y2_output_root_mean_squared_error: 3.0944 - val_loss: 28.4876 - val_y1_output_loss: 11.1373 - val_y2_output_loss: 17.5535 - val_y1_output_root_mean_squared_error: 3.3266 - val_y2_output_root_mean_squared_error: 4.1739
# Epoch 20/500
# 614/614 [==============================] - 0s 161us/sample - loss: 15.9683 - y1_output_loss: 5.8707 - y2_output_loss: 9.9770 - y1_output_root_mean_squared_error: 2.4336 - y2_output_root_mean_squared_error: 3.1695 - val_loss: 12.7306 - val_y1_output_loss: 5.2307 - val_y2_output_loss: 7.0598 - val_y1_output_root_mean_squared_error: 2.3255 - val_y2_output_root_mean_squared_error: 2.7060
# Epoch 21/500
# 614/614 [==============================] - 0s 143us/sample - loss: 15.2565 - y1_output_loss: 5.5805 - y2_output_loss: 9.5798 - y1_output_root_mean_squared_error: 2.3729 - y2_output_root_mean_squared_error: 3.1025 - val_loss: 15.0564 - val_y1_output_loss: 7.2874 - val_y2_output_loss: 7.2541 - val_y1_output_root_mean_squared_error: 2.7440 - val_y2_output_root_mean_squared_error: 2.7435
# Epoch 22/500
# 614/614 [==============================] - 0s 141us/sample - loss: 13.9698 - y1_output_loss: 5.5051 - y2_output_loss: 8.4455 - y1_output_root_mean_squared_error: 2.3548 - y2_output_root_mean_squared_error: 2.9025 - val_loss: 32.7084 - val_y1_output_loss: 7.1631 - val_y2_output_loss: 24.6793 - val_y1_output_root_mean_squared_error: 2.7196 - val_y2_output_root_mean_squared_error: 5.0311
# Epoch 23/500
# 614/614 [==============================] - 0s 152us/sample - loss: 14.9612 - y1_output_loss: 5.0540 - y2_output_loss: 9.8500 - y1_output_root_mean_squared_error: 2.2477 - y2_output_root_mean_squared_error: 3.1479 - val_loss: 14.8048 - val_y1_output_loss: 6.1955 - val_y2_output_loss: 8.1300 - val_y1_output_root_mean_squared_error: 2.5289 - val_y2_output_root_mean_squared_error: 2.8999
# Epoch 24/500
# 614/614 [==============================] - 0s 144us/sample - loss: 14.6270 - y1_output_loss: 5.0973 - y2_output_loss: 10.3507 - y1_output_root_mean_squared_error: 2.2201 - y2_output_root_mean_squared_error: 3.1142 - val_loss: 102.0596 - val_y1_output_loss: 15.6314 - val_y2_output_loss: 85.4425 - val_y1_output_root_mean_squared_error: 3.9762 - val_y2_output_root_mean_squared_error: 9.2871
# Epoch 25/500
# 614/614 [==============================] - 0s 154us/sample - loss: 14.2301 - y1_output_loss: 4.5899 - y2_output_loss: 9.5929 - y1_output_root_mean_squared_error: 2.1372 - y2_output_root_mean_squared_error: 3.1085 - val_loss: 13.1882 - val_y1_output_loss: 5.5243 - val_y2_output_loss: 7.2645 - val_y1_output_root_mean_squared_error: 2.3901 - val_y2_output_root_mean_squared_error: 2.7342
# Epoch 26/500
# 614/614 [==============================] - 0s 168us/sample - loss: 11.9258 - y1_output_loss: 4.5192 - y2_output_loss: 7.5225 - y1_output_root_mean_squared_error: 2.1066 - y2_output_root_mean_squared_error: 2.7364 - val_loss: 35.2308 - val_y1_output_loss: 10.4844 - val_y2_output_loss: 24.1777 - val_y1_output_root_mean_squared_error: 3.2750 - val_y2_output_root_mean_squared_error: 4.9503
# Epoch 27/500
# 614/614 [==============================] - 0s 146us/sample - loss: 12.8983 - y1_output_loss: 4.1721 - y2_output_loss: 8.6711 - y1_output_root_mean_squared_error: 2.0480 - y2_output_root_mean_squared_error: 2.9502 - val_loss: 18.6239 - val_y1_output_loss: 5.4267 - val_y2_output_loss: 12.7472 - val_y1_output_root_mean_squared_error: 2.3594 - val_y2_output_root_mean_squared_error: 3.6135
# Epoch 28/500
# 614/614 [==============================] - 0s 142us/sample - loss: 11.2437 - y1_output_loss: 3.9880 - y2_output_loss: 7.1961 - y1_output_root_mean_squared_error: 2.0054 - y2_output_root_mean_squared_error: 2.6874 - val_loss: 12.5458 - val_y1_output_loss: 4.7068 - val_y2_output_loss: 7.3840 - val_y1_output_root_mean_squared_error: 2.2104 - val_y2_output_root_mean_squared_error: 2.7677
# Epoch 29/500
# 614/614 [==============================] - 0s 152us/sample - loss: 11.7598 - y1_output_loss: 3.9110 - y2_output_loss: 7.7703 - y1_output_root_mean_squared_error: 1.9836 - y2_output_root_mean_squared_error: 2.7973 - val_loss: 9.0910 - val_y1_output_loss: 3.6959 - val_y2_output_loss: 5.1230 - val_y1_output_root_mean_squared_error: 1.9573 - val_y2_output_root_mean_squared_error: 2.2935
# Epoch 30/500
# 614/614 [==============================] - 0s 143us/sample - loss: 10.4269 - y1_output_loss: 3.6428 - y2_output_loss: 6.6948 - y1_output_root_mean_squared_error: 1.9150 - y2_output_root_mean_squared_error: 2.5999 - val_loss: 12.6562 - val_y1_output_loss: 4.7797 - val_y2_output_loss: 7.4378 - val_y1_output_root_mean_squared_error: 2.2251 - val_y2_output_root_mean_squared_error: 2.7758
# Epoch 31/500
# 614/614 [==============================] - 0s 155us/sample - loss: 8.2618 - y1_output_loss: 3.1184 - y2_output_loss: 5.1162 - y1_output_root_mean_squared_error: 1.7604 - y2_output_root_mean_squared_error: 2.2722 - val_loss: 8.7651 - val_y1_output_loss: 3.6404 - val_y2_output_loss: 4.8726 - val_y1_output_root_mean_squared_error: 1.9399 - val_y2_output_root_mean_squared_error: 2.2365
# Epoch 32/500
# 614/614 [==============================] - 0s 162us/sample - loss: 10.1988 - y1_output_loss: 3.4444 - y2_output_loss: 6.7723 - y1_output_root_mean_squared_error: 1.8649 - y2_output_root_mean_squared_error: 2.5925 - val_loss: 9.1079 - val_y1_output_loss: 3.0700 - val_y2_output_loss: 5.7812 - val_y1_output_root_mean_squared_error: 1.7853 - val_y2_output_root_mean_squared_error: 2.4333
# Epoch 33/500
# 614/614 [==============================] - 0s 139us/sample - loss: 11.3396 - y1_output_loss: 3.5117 - y2_output_loss: 7.9093 - y1_output_root_mean_squared_error: 1.8775 - y2_output_root_mean_squared_error: 2.7955 - val_loss: 15.3166 - val_y1_output_loss: 3.4095 - val_y2_output_loss: 11.4308 - val_y1_output_root_mean_squared_error: 1.8812 - val_y2_output_root_mean_squared_error: 3.4319
# Epoch 34/500
# 614/614 [==============================] - 0s 143us/sample - loss: 9.7372 - y1_output_loss: 3.3104 - y2_output_loss: 6.3364 - y1_output_root_mean_squared_error: 1.8282 - y2_output_root_mean_squared_error: 2.5288 - val_loss: 12.6205 - val_y1_output_loss: 4.0893 - val_y2_output_loss: 8.0765 - val_y1_output_root_mean_squared_error: 2.0607 - val_y2_output_root_mean_squared_error: 2.8938
# Epoch 35/500
# 614/614 [==============================] - 0s 153us/sample - loss: 8.2085 - y1_output_loss: 2.7837 - y2_output_loss: 5.3511 - y1_output_root_mean_squared_error: 1.6753 - y2_output_root_mean_squared_error: 2.3242 - val_loss: 17.3889 - val_y1_output_loss: 4.6864 - val_y2_output_loss: 12.1365 - val_y1_output_root_mean_squared_error: 2.2041 - val_y2_output_root_mean_squared_error: 3.5399
# Epoch 36/500
# 614/614 [==============================] - 0s 140us/sample - loss: 8.0004 - y1_output_loss: 2.8008 - y2_output_loss: 5.1733 - y1_output_root_mean_squared_error: 1.6776 - y2_output_root_mean_squared_error: 2.2773 - val_loss: 9.0888 - val_y1_output_loss: 2.8529 - val_y2_output_loss: 5.9205 - val_y1_output_root_mean_squared_error: 1.7193 - val_y2_output_root_mean_squared_error: 2.4765
# Epoch 37/500
# 614/614 [==============================] - 0s 153us/sample - loss: 14.3399 - y1_output_loss: 4.5958 - y2_output_loss: 9.6983 - y1_output_root_mean_squared_error: 2.1502 - y2_output_root_mean_squared_error: 3.1171 - val_loss: 10.5512 - val_y1_output_loss: 4.0271 - val_y2_output_loss: 6.1490 - val_y1_output_root_mean_squared_error: 2.0439 - val_y2_output_root_mean_squared_error: 2.5247
# Epoch 38/500
# 614/614 [==============================] - 0s 159us/sample - loss: 7.4676 - y1_output_loss: 2.6178 - y2_output_loss: 4.8392 - y1_output_root_mean_squared_error: 1.6184 - y2_output_root_mean_squared_error: 2.2019 - val_loss: 9.7769 - val_y1_output_loss: 3.0443 - val_y2_output_loss: 6.4184 - val_y1_output_root_mean_squared_error: 1.7738 - val_y2_output_root_mean_squared_error: 2.5750
# Epoch 39/500
# 614/614 [==============================] - 0s 142us/sample - loss: 7.7025 - y1_output_loss: 2.5638 - y2_output_loss: 5.0757 - y1_output_root_mean_squared_error: 1.6075 - y2_output_root_mean_squared_error: 2.2624 - val_loss: 6.5440 - val_y1_output_loss: 2.4134 - val_y2_output_loss: 3.9205 - val_y1_output_root_mean_squared_error: 1.5830 - val_y2_output_root_mean_squared_error: 2.0095
# Epoch 40/500
# 614/614 [==============================] - 0s 147us/sample - loss: 8.4659 - y1_output_loss: 2.7010 - y2_output_loss: 5.7444 - y1_output_root_mean_squared_error: 1.6499 - y2_output_root_mean_squared_error: 2.3966 - val_loss: 8.3770 - val_y1_output_loss: 3.3733 - val_y2_output_loss: 4.7299 - val_y1_output_root_mean_squared_error: 1.8716 - val_y2_output_root_mean_squared_error: 2.2077
# Epoch 41/500
# 614/614 [==============================] - 0s 151us/sample - loss: 10.9264 - y1_output_loss: 3.5662 - y2_output_loss: 7.2681 - y1_output_root_mean_squared_error: 1.8971 - y2_output_root_mean_squared_error: 2.7069 - val_loss: 9.1358 - val_y1_output_loss: 3.4511 - val_y2_output_loss: 5.3574 - val_y1_output_root_mean_squared_error: 1.8926 - val_y2_output_root_mean_squared_error: 2.3567
# Epoch 42/500
# 614/614 [==============================] - 0s 145us/sample - loss: 14.2356 - y1_output_loss: 4.3979 - y2_output_loss: 9.7286 - y1_output_root_mean_squared_error: 2.1037 - y2_output_root_mean_squared_error: 3.1321 - val_loss: 6.8504 - val_y1_output_loss: 2.4975 - val_y2_output_loss: 4.1922 - val_y1_output_root_mean_squared_error: 1.6099 - val_y2_output_root_mean_squared_error: 2.0636
# Epoch 43/500
# 614/614 [==============================] - 0s 154us/sample - loss: 6.8086 - y1_output_loss: 2.1564 - y2_output_loss: 4.6006 - y1_output_root_mean_squared_error: 1.4710 - y2_output_root_mean_squared_error: 2.1552 - val_loss: 6.2298 - val_y1_output_loss: 2.2811 - val_y2_output_loss: 3.8002 - val_y1_output_root_mean_squared_error: 1.5330 - val_y2_output_root_mean_squared_error: 1.9697
# Epoch 44/500
# 614/614 [==============================] - 0s 170us/sample - loss: 7.4304 - y1_output_loss: 2.4847 - y2_output_loss: 4.9777 - y1_output_root_mean_squared_error: 1.5705 - y2_output_root_mean_squared_error: 2.2280 - val_loss: 7.8421 - val_y1_output_loss: 2.9686 - val_y2_output_loss: 4.7405 - val_y1_output_root_mean_squared_error: 1.7400 - val_y2_output_root_mean_squared_error: 2.1942
# Epoch 45/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.7470 - y1_output_loss: 2.5838 - y2_output_loss: 6.0979 - y1_output_root_mean_squared_error: 1.6123 - y2_output_root_mean_squared_error: 2.4794 - val_loss: 9.6657 - val_y1_output_loss: 3.1845 - val_y2_output_loss: 6.2681 - val_y1_output_root_mean_squared_error: 1.8031 - val_y2_output_root_mean_squared_error: 2.5327
# Epoch 46/500
# 614/614 [==============================] - 0s 150us/sample - loss: 8.8366 - y1_output_loss: 2.5562 - y2_output_loss: 6.2461 - y1_output_root_mean_squared_error: 1.6059 - y2_output_root_mean_squared_error: 2.5015 - val_loss: 10.9134 - val_y1_output_loss: 2.6933 - val_y2_output_loss: 7.8797 - val_y1_output_root_mean_squared_error: 1.6707 - val_y2_output_root_mean_squared_error: 2.8499
# Epoch 47/500
# 614/614 [==============================] - 0s 155us/sample - loss: 7.7475 - y1_output_loss: 2.2988 - y2_output_loss: 5.4521 - y1_output_root_mean_squared_error: 1.5154 - y2_output_root_mean_squared_error: 2.3348 - val_loss: 5.7730 - val_y1_output_loss: 2.0109 - val_y2_output_loss: 3.5679 - val_y1_output_root_mean_squared_error: 1.4437 - val_y2_output_root_mean_squared_error: 1.9206
# Epoch 48/500
# 614/614 [==============================] - 0s 152us/sample - loss: 6.4775 - y1_output_loss: 2.1158 - y2_output_loss: 4.3320 - y1_output_root_mean_squared_error: 1.4586 - y2_output_root_mean_squared_error: 2.0857 - val_loss: 7.6102 - val_y1_output_loss: 2.4402 - val_y2_output_loss: 4.9118 - val_y1_output_root_mean_squared_error: 1.5891 - val_y2_output_root_mean_squared_error: 2.2550
# Epoch 49/500
# 614/614 [==============================] - 0s 152us/sample - loss: 5.8219 - y1_output_loss: 1.8101 - y2_output_loss: 3.9918 - y1_output_root_mean_squared_error: 1.3487 - y2_output_root_mean_squared_error: 2.0007 - val_loss: 11.6577 - val_y1_output_loss: 2.7714 - val_y2_output_loss: 8.4722 - val_y1_output_root_mean_squared_error: 1.6963 - val_y2_output_root_mean_squared_error: 2.9632
# Epoch 50/500
# 614/614 [==============================] - 0s 159us/sample - loss: 7.7200 - y1_output_loss: 2.4462 - y2_output_loss: 5.3390 - y1_output_root_mean_squared_error: 1.5504 - y2_output_root_mean_squared_error: 2.3057 - val_loss: 11.2136 - val_y1_output_loss: 3.4966 - val_y2_output_loss: 7.4358 - val_y1_output_root_mean_squared_error: 1.9006 - val_y2_output_root_mean_squared_error: 2.7571
# Epoch 51/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.7996 - y1_output_loss: 2.7361 - y2_output_loss: 6.0776 - y1_output_root_mean_squared_error: 1.6550 - y2_output_root_mean_squared_error: 2.4619 - val_loss: 6.9237 - val_y1_output_loss: 1.8450 - val_y2_output_loss: 4.8630 - val_y1_output_root_mean_squared_error: 1.3800 - val_y2_output_root_mean_squared_error: 2.2404
# Epoch 52/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.3363 - y1_output_loss: 1.9384 - y2_output_loss: 4.3964 - y1_output_root_mean_squared_error: 1.3958 - y2_output_root_mean_squared_error: 2.0948 - val_loss: 8.1249 - val_y1_output_loss: 2.9247 - val_y2_output_loss: 4.9162 - val_y1_output_root_mean_squared_error: 1.7412 - val_y2_output_root_mean_squared_error: 2.2568
# Epoch 53/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.5441 - y1_output_loss: 1.8685 - y2_output_loss: 4.6798 - y1_output_root_mean_squared_error: 1.3621 - y2_output_root_mean_squared_error: 2.1653 - val_loss: 5.3026 - val_y1_output_loss: 2.0046 - val_y2_output_loss: 3.1337 - val_y1_output_root_mean_squared_error: 1.4358 - val_y2_output_root_mean_squared_error: 1.8003
# Epoch 54/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.3689 - y1_output_loss: 1.7198 - y2_output_loss: 3.6806 - y1_output_root_mean_squared_error: 1.3076 - y2_output_root_mean_squared_error: 1.9129 - val_loss: 6.6438 - val_y1_output_loss: 1.7945 - val_y2_output_loss: 4.6329 - val_y1_output_root_mean_squared_error: 1.3604 - val_y2_output_root_mean_squared_error: 2.1893
# Epoch 55/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.9270 - y1_output_loss: 1.9096 - y2_output_loss: 3.9773 - y1_output_root_mean_squared_error: 1.3855 - y2_output_root_mean_squared_error: 2.0019 - val_loss: 4.9735 - val_y1_output_loss: 1.6240 - val_y2_output_loss: 3.1795 - val_y1_output_root_mean_squared_error: 1.2970 - val_y2_output_root_mean_squared_error: 1.8142
# Epoch 56/500
# 614/614 [==============================] - 0s 163us/sample - loss: 6.0415 - y1_output_loss: 1.8300 - y2_output_loss: 4.1575 - y1_output_root_mean_squared_error: 1.3587 - y2_output_root_mean_squared_error: 2.0483 - val_loss: 12.7989 - val_y1_output_loss: 3.6596 - val_y2_output_loss: 8.6715 - val_y1_output_root_mean_squared_error: 1.9494 - val_y2_output_root_mean_squared_error: 2.9998
# Epoch 57/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.1743 - y1_output_loss: 1.8471 - y2_output_loss: 4.3401 - y1_output_root_mean_squared_error: 1.3603 - y2_output_root_mean_squared_error: 2.0794 - val_loss: 5.6992 - val_y1_output_loss: 1.7039 - val_y2_output_loss: 4.0057 - val_y1_output_root_mean_squared_error: 1.3075 - val_y2_output_root_mean_squared_error: 1.9974
# Epoch 58/500
# 614/614 [==============================] - 0s 173us/sample - loss: 5.4423 - y1_output_loss: 1.5462 - y2_output_loss: 3.8955 - y1_output_root_mean_squared_error: 1.2367 - y2_output_root_mean_squared_error: 1.9781 - val_loss: 5.7016 - val_y1_output_loss: 1.4564 - val_y2_output_loss: 4.0484 - val_y1_output_root_mean_squared_error: 1.2265 - val_y2_output_root_mean_squared_error: 2.0487
# Epoch 59/500
# 614/614 [==============================] - 0s 153us/sample - loss: 5.6643 - y1_output_loss: 1.7207 - y2_output_loss: 3.9937 - y1_output_root_mean_squared_error: 1.3081 - y2_output_root_mean_squared_error: 1.9883 - val_loss: 5.3008 - val_y1_output_loss: 1.7985 - val_y2_output_loss: 3.3924 - val_y1_output_root_mean_squared_error: 1.3576 - val_y2_output_root_mean_squared_error: 1.8595
# Epoch 60/500
# 614/614 [==============================] - 0s 157us/sample - loss: 5.7239 - y1_output_loss: 1.6603 - y2_output_loss: 4.0625 - y1_output_root_mean_squared_error: 1.2936 - y2_output_root_mean_squared_error: 2.0126 - val_loss: 4.9798 - val_y1_output_loss: 1.5453 - val_y2_output_loss: 3.2789 - val_y1_output_root_mean_squared_error: 1.2622 - val_y2_output_root_mean_squared_error: 1.8403
# Epoch 61/500
# 614/614 [==============================] - 0s 147us/sample - loss: 5.3363 - y1_output_loss: 1.4652 - y2_output_loss: 3.8650 - y1_output_root_mean_squared_error: 1.2098 - y2_output_root_mean_squared_error: 1.9679 - val_loss: 12.5848 - val_y1_output_loss: 3.0360 - val_y2_output_loss: 9.2527 - val_y1_output_root_mean_squared_error: 1.7611 - val_y2_output_root_mean_squared_error: 3.0795
# Epoch 62/500
# 614/614 [==============================] - 0s 164us/sample - loss: 7.3122 - y1_output_loss: 2.1171 - y2_output_loss: 5.2535 - y1_output_root_mean_squared_error: 1.4533 - y2_output_root_mean_squared_error: 2.2804 - val_loss: 12.6879 - val_y1_output_loss: 3.2261 - val_y2_output_loss: 9.4541 - val_y1_output_root_mean_squared_error: 1.7930 - val_y2_output_root_mean_squared_error: 3.0779
# Epoch 63/500
# 614/614 [==============================] - 0s 146us/sample - loss: 8.1214 - y1_output_loss: 2.3365 - y2_output_loss: 5.7616 - y1_output_root_mean_squared_error: 1.5270 - y2_output_root_mean_squared_error: 2.4062 - val_loss: 7.5393 - val_y1_output_loss: 3.0299 - val_y2_output_loss: 4.3046 - val_y1_output_root_mean_squared_error: 1.7614 - val_y2_output_root_mean_squared_error: 2.1064
# Epoch 64/500
# 614/614 [==============================] - 0s 165us/sample - loss: 5.1937 - y1_output_loss: 1.4054 - y2_output_loss: 3.7987 - y1_output_root_mean_squared_error: 1.1884 - y2_output_root_mean_squared_error: 1.9446 - val_loss: 9.3989 - val_y1_output_loss: 1.4842 - val_y2_output_loss: 7.7983 - val_y1_output_root_mean_squared_error: 1.2323 - val_y2_output_root_mean_squared_error: 2.8072
# Epoch 65/500
# 614/614 [==============================] - 0s 164us/sample - loss: 5.5456 - y1_output_loss: 1.3646 - y2_output_loss: 4.2499 - y1_output_root_mean_squared_error: 1.1668 - y2_output_root_mean_squared_error: 2.0455 - val_loss: 9.2048 - val_y1_output_loss: 1.9635 - val_y2_output_loss: 7.0400 - val_y1_output_root_mean_squared_error: 1.4215 - val_y2_output_root_mean_squared_error: 2.6803
# Epoch 66/500
# 614/614 [==============================] - 0s 163us/sample - loss: 5.1876 - y1_output_loss: 1.2133 - y2_output_loss: 3.9422 - y1_output_root_mean_squared_error: 1.1027 - y2_output_root_mean_squared_error: 1.9929 - val_loss: 5.2911 - val_y1_output_loss: 1.7455 - val_y2_output_loss: 3.4005 - val_y1_output_root_mean_squared_error: 1.3360 - val_y2_output_root_mean_squared_error: 1.8725
# Epoch 67/500
# 614/614 [==============================] - 0s 162us/sample - loss: 5.0725 - y1_output_loss: 1.3760 - y2_output_loss: 3.6858 - y1_output_root_mean_squared_error: 1.1676 - y2_output_root_mean_squared_error: 1.9259 - val_loss: 5.5628 - val_y1_output_loss: 1.3706 - val_y2_output_loss: 4.2207 - val_y1_output_root_mean_squared_error: 1.1634 - val_y2_output_root_mean_squared_error: 2.0517
# Epoch 68/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.2978 - y1_output_loss: 1.1301 - y2_output_loss: 3.1537 - y1_output_root_mean_squared_error: 1.0666 - y2_output_root_mean_squared_error: 1.7777 - val_loss: 4.6104 - val_y1_output_loss: 1.0991 - val_y2_output_loss: 3.4630 - val_y1_output_root_mean_squared_error: 1.0595 - val_y2_output_root_mean_squared_error: 1.8676
# Epoch 69/500
# 614/614 [==============================] - 0s 154us/sample - loss: 6.0511 - y1_output_loss: 1.7326 - y2_output_loss: 4.8501 - y1_output_root_mean_squared_error: 1.2604 - y2_output_root_mean_squared_error: 2.1125 - val_loss: 17.8709 - val_y1_output_loss: 6.6752 - val_y2_output_loss: 11.0058 - val_y1_output_root_mean_squared_error: 2.5836 - val_y2_output_root_mean_squared_error: 3.3460
# Epoch 70/500
# 614/614 [==============================] - 0s 152us/sample - loss: 9.0137 - y1_output_loss: 2.5596 - y2_output_loss: 6.3907 - y1_output_root_mean_squared_error: 1.6060 - y2_output_root_mean_squared_error: 2.5367 - val_loss: 5.7224 - val_y1_output_loss: 1.1220 - val_y2_output_loss: 4.4193 - val_y1_output_root_mean_squared_error: 1.0777 - val_y2_output_root_mean_squared_error: 2.1357
# Epoch 71/500
# 614/614 [==============================] - 0s 159us/sample - loss: 5.0007 - y1_output_loss: 1.1777 - y2_output_loss: 3.7951 - y1_output_root_mean_squared_error: 1.0845 - y2_output_root_mean_squared_error: 1.9557 - val_loss: 5.6510 - val_y1_output_loss: 1.5963 - val_y2_output_loss: 3.8862 - val_y1_output_root_mean_squared_error: 1.2798 - val_y2_output_root_mean_squared_error: 2.0033
# Epoch 72/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.9772 - y1_output_loss: 1.3951 - y2_output_loss: 3.6149 - y1_output_root_mean_squared_error: 1.1769 - y2_output_root_mean_squared_error: 1.8953 - val_loss: 9.3707 - val_y1_output_loss: 4.0271 - val_y2_output_loss: 5.5327 - val_y1_output_root_mean_squared_error: 1.9803 - val_y2_output_root_mean_squared_error: 2.3343
# Epoch 73/500
# 614/614 [==============================] - 0s 160us/sample - loss: 4.7947 - y1_output_loss: 1.2612 - y2_output_loss: 3.5098 - y1_output_root_mean_squared_error: 1.1263 - y2_output_root_mean_squared_error: 1.8778 - val_loss: 6.3490 - val_y1_output_loss: 2.1462 - val_y2_output_loss: 4.1543 - val_y1_output_root_mean_squared_error: 1.4619 - val_y2_output_root_mean_squared_error: 2.0523
# Epoch 74/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.7952 - y1_output_loss: 1.4610 - y2_output_loss: 3.3102 - y1_output_root_mean_squared_error: 1.2104 - y2_output_root_mean_squared_error: 1.8249 - val_loss: 5.6338 - val_y1_output_loss: 1.8828 - val_y2_output_loss: 3.6057 - val_y1_output_root_mean_squared_error: 1.3968 - val_y2_output_root_mean_squared_error: 1.9190
# Epoch 75/500
# 614/614 [==============================] - 0s 150us/sample - loss: 4.4773 - y1_output_loss: 1.0812 - y2_output_loss: 3.3834 - y1_output_root_mean_squared_error: 1.0446 - y2_output_root_mean_squared_error: 1.8401 - val_loss: 7.0726 - val_y1_output_loss: 2.9982 - val_y2_output_loss: 4.0608 - val_y1_output_root_mean_squared_error: 1.7240 - val_y2_output_root_mean_squared_error: 2.0250
# Epoch 76/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.6716 - y1_output_loss: 0.8927 - y2_output_loss: 2.7618 - y1_output_root_mean_squared_error: 0.9430 - y2_output_root_mean_squared_error: 1.6681 - val_loss: 3.4241 - val_y1_output_loss: 0.8798 - val_y2_output_loss: 2.4229 - val_y1_output_root_mean_squared_error: 0.9551 - val_y2_output_root_mean_squared_error: 1.5849
# Epoch 77/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.9355 - y1_output_loss: 0.9628 - y2_output_loss: 3.0116 - y1_output_root_mean_squared_error: 0.9662 - y2_output_root_mean_squared_error: 1.7326 - val_loss: 5.9804 - val_y1_output_loss: 2.1875 - val_y2_output_loss: 3.5785 - val_y1_output_root_mean_squared_error: 1.5068 - val_y2_output_root_mean_squared_error: 1.9261
# Epoch 78/500
# 614/614 [==============================] - 0s 149us/sample - loss: 3.1909 - y1_output_loss: 0.8356 - y2_output_loss: 2.3589 - y1_output_root_mean_squared_error: 0.9177 - y2_output_root_mean_squared_error: 1.5325 - val_loss: 5.7741 - val_y1_output_loss: 1.2374 - val_y2_output_loss: 4.3311 - val_y1_output_root_mean_squared_error: 1.1334 - val_y2_output_root_mean_squared_error: 2.1189
# Epoch 79/500
# 614/614 [==============================] - 0s 159us/sample - loss: 5.4767 - y1_output_loss: 1.3901 - y2_output_loss: 4.1161 - y1_output_root_mean_squared_error: 1.1806 - y2_output_root_mean_squared_error: 2.0206 - val_loss: 7.0077 - val_y1_output_loss: 1.3703 - val_y2_output_loss: 5.4068 - val_y1_output_root_mean_squared_error: 1.1925 - val_y2_output_root_mean_squared_error: 2.3634
# Epoch 80/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.1808 - y1_output_loss: 1.0580 - y2_output_loss: 3.1213 - y1_output_root_mean_squared_error: 1.0277 - y2_output_root_mean_squared_error: 1.7676 - val_loss: 3.6055 - val_y1_output_loss: 1.0344 - val_y2_output_loss: 2.4636 - val_y1_output_root_mean_squared_error: 1.0337 - val_y2_output_root_mean_squared_error: 1.5928
# Epoch 81/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.4419 - y1_output_loss: 0.7797 - y2_output_loss: 2.6383 - y1_output_root_mean_squared_error: 0.8851 - y2_output_root_mean_squared_error: 1.6305 - val_loss: 3.6506 - val_y1_output_loss: 0.7901 - val_y2_output_loss: 2.7505 - val_y1_output_root_mean_squared_error: 0.9004 - val_y2_output_root_mean_squared_error: 1.6852
# Epoch 82/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.6520 - y1_output_loss: 0.8561 - y2_output_loss: 2.7697 - y1_output_root_mean_squared_error: 0.9270 - y2_output_root_mean_squared_error: 1.6711 - val_loss: 3.0291 - val_y1_output_loss: 0.6425 - val_y2_output_loss: 2.2931 - val_y1_output_root_mean_squared_error: 0.8093 - val_y2_output_root_mean_squared_error: 1.5408
# Epoch 83/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.1747 - y1_output_loss: 0.6895 - y2_output_loss: 2.4604 - y1_output_root_mean_squared_error: 0.8332 - y2_output_root_mean_squared_error: 1.5749 - val_loss: 3.0198 - val_y1_output_loss: 0.7882 - val_y2_output_loss: 2.1634 - val_y1_output_root_mean_squared_error: 0.8942 - val_y2_output_root_mean_squared_error: 1.4901
# Epoch 84/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.9888 - y1_output_loss: 1.0508 - y2_output_loss: 2.9190 - y1_output_root_mean_squared_error: 1.0240 - y2_output_root_mean_squared_error: 1.7147 - val_loss: 3.4964 - val_y1_output_loss: 1.1301 - val_y2_output_loss: 2.2481 - val_y1_output_root_mean_squared_error: 1.0806 - val_y2_output_root_mean_squared_error: 1.5260
# Epoch 85/500
# 614/614 [==============================] - 0s 166us/sample - loss: 4.0086 - y1_output_loss: 1.1627 - y2_output_loss: 2.8528 - y1_output_root_mean_squared_error: 1.0801 - y2_output_root_mean_squared_error: 1.6858 - val_loss: 3.1038 - val_y1_output_loss: 0.8788 - val_y2_output_loss: 2.1810 - val_y1_output_root_mean_squared_error: 0.9379 - val_y2_output_root_mean_squared_error: 1.4914
# Epoch 86/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.9640 - y1_output_loss: 0.7006 - y2_output_loss: 2.2513 - y1_output_root_mean_squared_error: 0.8380 - y2_output_root_mean_squared_error: 1.5039 - val_loss: 3.3507 - val_y1_output_loss: 1.0243 - val_y2_output_loss: 2.3143 - val_y1_output_root_mean_squared_error: 1.0119 - val_y2_output_root_mean_squared_error: 1.5254
# Epoch 87/500
# 614/614 [==============================] - 0s 151us/sample - loss: 4.2470 - y1_output_loss: 1.1095 - y2_output_loss: 3.1086 - y1_output_root_mean_squared_error: 1.0576 - y2_output_root_mean_squared_error: 1.7688 - val_loss: 3.1976 - val_y1_output_loss: 0.8960 - val_y2_output_loss: 2.2483 - val_y1_output_root_mean_squared_error: 0.9548 - val_y2_output_root_mean_squared_error: 1.5119
# Epoch 88/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.6634 - y1_output_loss: 0.9371 - y2_output_loss: 2.7070 - y1_output_root_mean_squared_error: 0.9666 - y2_output_root_mean_squared_error: 1.6520 - val_loss: 3.1972 - val_y1_output_loss: 0.7391 - val_y2_output_loss: 2.3977 - val_y1_output_root_mean_squared_error: 0.8675 - val_y2_output_root_mean_squared_error: 1.5635
# Epoch 89/500
# 614/614 [==============================] - 0s 163us/sample - loss: 3.6174 - y1_output_loss: 0.9051 - y2_output_loss: 2.6934 - y1_output_root_mean_squared_error: 0.9524 - y2_output_root_mean_squared_error: 1.6463 - val_loss: 5.2741 - val_y1_output_loss: 1.4632 - val_y2_output_loss: 3.7283 - val_y1_output_root_mean_squared_error: 1.2152 - val_y2_output_root_mean_squared_error: 1.9487
# Epoch 90/500
# 614/614 [==============================] - 0s 163us/sample - loss: 3.3833 - y1_output_loss: 0.7786 - y2_output_loss: 2.5755 - y1_output_root_mean_squared_error: 0.8862 - y2_output_root_mean_squared_error: 1.6118 - val_loss: 2.8437 - val_y1_output_loss: 0.6821 - val_y2_output_loss: 2.0919 - val_y1_output_root_mean_squared_error: 0.8316 - val_y2_output_root_mean_squared_error: 1.4670
# Epoch 91/500
# 614/614 [==============================] - 0s 178us/sample - loss: 3.1606 - y1_output_loss: 0.7572 - y2_output_loss: 2.3811 - y1_output_root_mean_squared_error: 0.8716 - y2_output_root_mean_squared_error: 1.5494 - val_loss: 2.8876 - val_y1_output_loss: 0.6909 - val_y2_output_loss: 2.1004 - val_y1_output_root_mean_squared_error: 0.8448 - val_y2_output_root_mean_squared_error: 1.4744
# Epoch 92/500
# 614/614 [==============================] - 0s 166us/sample - loss: 5.0787 - y1_output_loss: 1.4224 - y2_output_loss: 3.7093 - y1_output_root_mean_squared_error: 1.1971 - y2_output_root_mean_squared_error: 1.9094 - val_loss: 6.1409 - val_y1_output_loss: 0.9586 - val_y2_output_loss: 5.0331 - val_y1_output_root_mean_squared_error: 0.9936 - val_y2_output_root_mean_squared_error: 2.2702
# Epoch 93/500
# 614/614 [==============================] - 0s 164us/sample - loss: 3.5881 - y1_output_loss: 0.9703 - y2_output_loss: 2.6069 - y1_output_root_mean_squared_error: 0.9843 - y2_output_root_mean_squared_error: 1.6184 - val_loss: 4.7261 - val_y1_output_loss: 1.3492 - val_y2_output_loss: 3.2322 - val_y1_output_root_mean_squared_error: 1.1794 - val_y2_output_root_mean_squared_error: 1.8262
# Epoch 94/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.4938 - y1_output_loss: 0.6071 - y2_output_loss: 1.8686 - y1_output_root_mean_squared_error: 0.7804 - y2_output_root_mean_squared_error: 1.3729 - val_loss: 2.7336 - val_y1_output_loss: 0.6219 - val_y2_output_loss: 2.0167 - val_y1_output_root_mean_squared_error: 0.8020 - val_y2_output_root_mean_squared_error: 1.4458
# Epoch 95/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.6142 - y1_output_loss: 0.5905 - y2_output_loss: 2.0193 - y1_output_root_mean_squared_error: 0.7709 - y2_output_root_mean_squared_error: 1.4212 - val_loss: 7.2315 - val_y1_output_loss: 1.8020 - val_y2_output_loss: 5.1978 - val_y1_output_root_mean_squared_error: 1.3642 - val_y2_output_root_mean_squared_error: 2.3174
# Epoch 96/500
# 614/614 [==============================] - 0s 165us/sample - loss: 2.8971 - y1_output_loss: 0.6997 - y2_output_loss: 2.1923 - y1_output_root_mean_squared_error: 0.8403 - y2_output_root_mean_squared_error: 1.4802 - val_loss: 6.7462 - val_y1_output_loss: 0.8601 - val_y2_output_loss: 5.6782 - val_y1_output_root_mean_squared_error: 0.9433 - val_y2_output_root_mean_squared_error: 2.4200
# Epoch 97/500
# 614/614 [==============================] - 0s 163us/sample - loss: 2.7936 - y1_output_loss: 0.6427 - y2_output_loss: 2.1444 - y1_output_root_mean_squared_error: 0.7994 - y2_output_root_mean_squared_error: 1.4678 - val_loss: 4.0641 - val_y1_output_loss: 0.7820 - val_y2_output_loss: 3.1407 - val_y1_output_root_mean_squared_error: 0.8996 - val_y2_output_root_mean_squared_error: 1.8041
# Epoch 98/500
# 614/614 [==============================] - 0s 173us/sample - loss: 2.5429 - y1_output_loss: 0.5908 - y2_output_loss: 1.9596 - y1_output_root_mean_squared_error: 0.7707 - y2_output_root_mean_squared_error: 1.3960 - val_loss: 3.3247 - val_y1_output_loss: 0.9093 - val_y2_output_loss: 2.3554 - val_y1_output_root_mean_squared_error: 0.9509 - val_y2_output_root_mean_squared_error: 1.5558
# Epoch 99/500
# 614/614 [==============================] - 0s 191us/sample - loss: 2.4799 - y1_output_loss: 0.5215 - y2_output_loss: 1.9508 - y1_output_root_mean_squared_error: 0.7224 - y2_output_root_mean_squared_error: 1.3993 - val_loss: 2.9771 - val_y1_output_loss: 0.5607 - val_y2_output_loss: 2.3099 - val_y1_output_root_mean_squared_error: 0.7619 - val_y2_output_root_mean_squared_error: 1.5481
# Epoch 100/500
# 614/614 [==============================] - 0s 173us/sample - loss: 2.5377 - y1_output_loss: 0.5558 - y2_output_loss: 2.0532 - y1_output_root_mean_squared_error: 0.7421 - y2_output_root_mean_squared_error: 1.4096 - val_loss: 13.5826 - val_y1_output_loss: 4.0145 - val_y2_output_loss: 10.0861 - val_y1_output_root_mean_squared_error: 1.9345 - val_y2_output_root_mean_squared_error: 3.1369
# Epoch 101/500
# 614/614 [==============================] - 0s 154us/sample - loss: 4.0839 - y1_output_loss: 0.9893 - y2_output_loss: 3.0702 - y1_output_root_mean_squared_error: 0.9987 - y2_output_root_mean_squared_error: 1.7569 - val_loss: 3.7816 - val_y1_output_loss: 1.1491 - val_y2_output_loss: 2.6708 - val_y1_output_root_mean_squared_error: 1.0591 - val_y2_output_root_mean_squared_error: 1.6309
# Epoch 102/500
# 614/614 [==============================] - 0s 168us/sample - loss: 4.2085 - y1_output_loss: 0.9163 - y2_output_loss: 3.2659 - y1_output_root_mean_squared_error: 0.9614 - y2_output_root_mean_squared_error: 1.8123 - val_loss: 3.2400 - val_y1_output_loss: 0.7811 - val_y2_output_loss: 2.3557 - val_y1_output_root_mean_squared_error: 0.8972 - val_y2_output_root_mean_squared_error: 1.5604
# Epoch 103/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.4054 - y1_output_loss: 0.5770 - y2_output_loss: 1.8074 - y1_output_root_mean_squared_error: 0.7629 - y2_output_root_mean_squared_error: 1.3503 - val_loss: 2.5155 - val_y1_output_loss: 0.4868 - val_y2_output_loss: 1.9475 - val_y1_output_root_mean_squared_error: 0.7080 - val_y2_output_root_mean_squared_error: 1.4192
# Epoch 104/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.4012 - y1_output_loss: 0.5383 - y2_output_loss: 1.8565 - y1_output_root_mean_squared_error: 0.7336 - y2_output_root_mean_squared_error: 1.3649 - val_loss: 2.7555 - val_y1_output_loss: 0.8370 - val_y2_output_loss: 1.8235 - val_y1_output_root_mean_squared_error: 0.9319 - val_y2_output_root_mean_squared_error: 1.3737
# Epoch 105/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.3282 - y1_output_loss: 0.5891 - y2_output_loss: 1.7430 - y1_output_root_mean_squared_error: 0.7604 - y2_output_root_mean_squared_error: 1.3228 - val_loss: 2.7767 - val_y1_output_loss: 0.6717 - val_y2_output_loss: 2.0942 - val_y1_output_root_mean_squared_error: 0.8097 - val_y2_output_root_mean_squared_error: 1.4564
# Epoch 106/500
# 614/614 [==============================] - 0s 154us/sample - loss: 2.5171 - y1_output_loss: 0.4972 - y2_output_loss: 2.0410 - y1_output_root_mean_squared_error: 0.7056 - y2_output_root_mean_squared_error: 1.4210 - val_loss: 8.2293 - val_y1_output_loss: 0.8282 - val_y2_output_loss: 7.1628 - val_y1_output_root_mean_squared_error: 0.9259 - val_y2_output_root_mean_squared_error: 2.7152
# Epoch 107/500
# 614/614 [==============================] - 0s 162us/sample - loss: 3.2424 - y1_output_loss: 0.7157 - y2_output_loss: 2.4963 - y1_output_root_mean_squared_error: 0.8499 - y2_output_root_mean_squared_error: 1.5875 - val_loss: 2.5484 - val_y1_output_loss: 0.6325 - val_y2_output_loss: 1.8520 - val_y1_output_root_mean_squared_error: 0.7979 - val_y2_output_root_mean_squared_error: 1.3827
# Epoch 108/500
# 614/614 [==============================] - 0s 160us/sample - loss: 3.0946 - y1_output_loss: 0.5671 - y2_output_loss: 2.5034 - y1_output_root_mean_squared_error: 0.7548 - y2_output_root_mean_squared_error: 1.5890 - val_loss: 2.9643 - val_y1_output_loss: 0.6113 - val_y2_output_loss: 2.2746 - val_y1_output_root_mean_squared_error: 0.7925 - val_y2_output_root_mean_squared_error: 1.5285
# Epoch 109/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.5757 - y1_output_loss: 0.9206 - y2_output_loss: 2.6367 - y1_output_root_mean_squared_error: 0.9638 - y2_output_root_mean_squared_error: 1.6269 - val_loss: 3.5161 - val_y1_output_loss: 0.8208 - val_y2_output_loss: 2.5849 - val_y1_output_root_mean_squared_error: 0.9200 - val_y2_output_root_mean_squared_error: 1.6339
# Epoch 110/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.8937 - y1_output_loss: 0.6731 - y2_output_loss: 2.2037 - y1_output_root_mean_squared_error: 0.8236 - y2_output_root_mean_squared_error: 1.4884 - val_loss: 3.1823 - val_y1_output_loss: 0.7018 - val_y2_output_loss: 2.4166 - val_y1_output_root_mean_squared_error: 0.8426 - val_y2_output_root_mean_squared_error: 1.5723
# Epoch 111/500
# 614/614 [==============================] - 0s 169us/sample - loss: 2.6826 - y1_output_loss: 0.5587 - y2_output_loss: 2.4109 - y1_output_root_mean_squared_error: 0.7153 - y2_output_root_mean_squared_error: 1.4734 - val_loss: 88.1072 - val_y1_output_loss: 28.5365 - val_y2_output_loss: 60.8947 - val_y1_output_root_mean_squared_error: 5.2650 - val_y2_output_root_mean_squared_error: 7.7709
# Epoch 112/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.8907 - y1_output_loss: 0.9219 - y2_output_loss: 2.9336 - y1_output_root_mean_squared_error: 0.9643 - y2_output_root_mean_squared_error: 1.7207 - val_loss: 2.5712 - val_y1_output_loss: 0.5643 - val_y2_output_loss: 1.9184 - val_y1_output_root_mean_squared_error: 0.7633 - val_y2_output_root_mean_squared_error: 1.4102
# Epoch 113/500
# 614/614 [==============================] - 0s 169us/sample - loss: 2.0110 - y1_output_loss: 0.4521 - y2_output_loss: 1.5429 - y1_output_root_mean_squared_error: 0.6742 - y2_output_root_mean_squared_error: 1.2476 - val_loss: 2.8128 - val_y1_output_loss: 0.4716 - val_y2_output_loss: 2.2395 - val_y1_output_root_mean_squared_error: 0.6994 - val_y2_output_root_mean_squared_error: 1.5244
# Epoch 114/500
# 614/614 [==============================] - 0s 163us/sample - loss: 2.2178 - y1_output_loss: 0.4944 - y2_output_loss: 1.7306 - y1_output_root_mean_squared_error: 0.7031 - y2_output_root_mean_squared_error: 1.3128 - val_loss: 2.6551 - val_y1_output_loss: 0.6107 - val_y2_output_loss: 1.9514 - val_y1_output_root_mean_squared_error: 0.7944 - val_y2_output_root_mean_squared_error: 1.4227
# Epoch 115/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.2594 - y1_output_loss: 0.5340 - y2_output_loss: 1.7156 - y1_output_root_mean_squared_error: 0.7338 - y2_output_root_mean_squared_error: 1.3118 - val_loss: 3.3111 - val_y1_output_loss: 0.6257 - val_y2_output_loss: 2.6766 - val_y1_output_root_mean_squared_error: 0.7867 - val_y2_output_root_mean_squared_error: 1.6408
# Epoch 116/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.0700 - y1_output_loss: 0.4923 - y2_output_loss: 1.5863 - y1_output_root_mean_squared_error: 0.7011 - y2_output_root_mean_squared_error: 1.2563 - val_loss: 3.6493 - val_y1_output_loss: 1.0866 - val_y2_output_loss: 2.4915 - val_y1_output_root_mean_squared_error: 1.0398 - val_y2_output_root_mean_squared_error: 1.6025
# Epoch 117/500
# 614/614 [==============================] - 0s 156us/sample - loss: 1.8429 - y1_output_loss: 0.4111 - y2_output_loss: 1.4816 - y1_output_root_mean_squared_error: 0.6377 - y2_output_root_mean_squared_error: 1.1984 - val_loss: 11.2977 - val_y1_output_loss: 2.8391 - val_y2_output_loss: 8.2218 - val_y1_output_root_mean_squared_error: 1.7020 - val_y2_output_root_mean_squared_error: 2.8984
# Epoch 118/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.8633 - y1_output_loss: 0.6940 - y2_output_loss: 2.1540 - y1_output_root_mean_squared_error: 0.8361 - y2_output_root_mean_squared_error: 1.4711 - val_loss: 3.2147 - val_y1_output_loss: 0.9752 - val_y2_output_loss: 2.2356 - val_y1_output_root_mean_squared_error: 0.9805 - val_y2_output_root_mean_squared_error: 1.5011
# Epoch 119/500
# 614/614 [==============================] - 0s 163us/sample - loss: 3.1278 - y1_output_loss: 0.6663 - y2_output_loss: 2.4665 - y1_output_root_mean_squared_error: 0.8165 - y2_output_root_mean_squared_error: 1.5688 - val_loss: 6.6638 - val_y1_output_loss: 1.8264 - val_y2_output_loss: 4.7955 - val_y1_output_root_mean_squared_error: 1.3518 - val_y2_output_root_mean_squared_error: 2.1992
# Epoch 120/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.2819 - y1_output_loss: 0.5241 - y2_output_loss: 1.7382 - y1_output_root_mean_squared_error: 0.7268 - y2_output_root_mean_squared_error: 1.3242 - val_loss: 2.7879 - val_y1_output_loss: 0.6001 - val_y2_output_loss: 2.1009 - val_y1_output_root_mean_squared_error: 0.7837 - val_y2_output_root_mean_squared_error: 1.4743
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.5242 - y1_output_loss: 0.1160 - y2_output_loss: 0.4080 - y1_output_root_mean_squared_error: 0.3404 - y2_output_root_mean_squared_error: 0.6390 - val_loss: 1.1843 - val_y1_output_loss: 0.2441 - val_y2_output_loss: 0.9164 - val_y1_output_root_mean_squared_error: 0.4971 - val_y2_output_root_mean_squared_error: 0.9681
# Epoch 462/500
# 614/614 [==============================] - 0s 182us/sample - loss: 0.5112 - y1_output_loss: 0.1379 - y2_output_loss: 0.3923 - y1_output_root_mean_squared_error: 0.3703 - y2_output_root_mean_squared_error: 0.6116 - val_loss: 7.0292 - val_y1_output_loss: 0.6826 - val_y2_output_loss: 6.2422 - val_y1_output_root_mean_squared_error: 0.8295 - val_y2_output_root_mean_squared_error: 2.5182
# Epoch 463/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.6384 - y1_output_loss: 0.1280 - y2_output_loss: 0.5059 - y1_output_root_mean_squared_error: 0.3590 - y2_output_root_mean_squared_error: 0.7138 - val_loss: 1.1456 - val_y1_output_loss: 0.2730 - val_y2_output_loss: 0.8601 - val_y1_output_root_mean_squared_error: 0.5181 - val_y2_output_root_mean_squared_error: 0.9366
# Epoch 464/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4610 - y1_output_loss: 0.1213 - y2_output_loss: 0.3358 - y1_output_root_mean_squared_error: 0.3497 - y2_output_root_mean_squared_error: 0.5820 - val_loss: 0.9738 - val_y1_output_loss: 0.2120 - val_y2_output_loss: 0.7365 - val_y1_output_root_mean_squared_error: 0.4628 - val_y2_output_root_mean_squared_error: 0.8716
# Epoch 465/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.4361 - y1_output_loss: 0.1188 - y2_output_loss: 0.3150 - y1_output_root_mean_squared_error: 0.3449 - y2_output_root_mean_squared_error: 0.5631 - val_loss: 1.0999 - val_y1_output_loss: 0.2864 - val_y2_output_loss: 0.7949 - val_y1_output_root_mean_squared_error: 0.5329 - val_y2_output_root_mean_squared_error: 0.9033
# Epoch 466/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.5547 - y1_output_loss: 0.1274 - y2_output_loss: 0.4307 - y1_output_root_mean_squared_error: 0.3575 - y2_output_root_mean_squared_error: 0.6533 - val_loss: 1.4155 - val_y1_output_loss: 0.3220 - val_y2_output_loss: 1.0617 - val_y1_output_root_mean_squared_error: 0.5677 - val_y2_output_root_mean_squared_error: 1.0456
# Epoch 467/500
# 614/614 [==============================] - 0s 180us/sample - loss: 0.6647 - y1_output_loss: 0.1616 - y2_output_loss: 0.5022 - y1_output_root_mean_squared_error: 0.4009 - y2_output_root_mean_squared_error: 0.7099 - val_loss: 2.0608 - val_y1_output_loss: 0.4626 - val_y2_output_loss: 1.5397 - val_y1_output_root_mean_squared_error: 0.6916 - val_y2_output_root_mean_squared_error: 1.2580
# Epoch 468/500
# 614/614 [==============================] - 0s 168us/sample - loss: 0.7062 - y1_output_loss: 0.2126 - y2_output_loss: 0.4905 - y1_output_root_mean_squared_error: 0.4625 - y2_output_root_mean_squared_error: 0.7017 - val_loss: 1.2605 - val_y1_output_loss: 0.2315 - val_y2_output_loss: 0.9936 - val_y1_output_root_mean_squared_error: 0.4817 - val_y2_output_root_mean_squared_error: 1.0141
# Epoch 469/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4118 - y1_output_loss: 0.1146 - y2_output_loss: 0.2956 - y1_output_root_mean_squared_error: 0.3393 - y2_output_root_mean_squared_error: 0.5447 - val_loss: 1.0771 - val_y1_output_loss: 0.2475 - val_y2_output_loss: 0.8035 - val_y1_output_root_mean_squared_error: 0.4991 - val_y2_output_root_mean_squared_error: 0.9099
# Epoch 470/500
# 614/614 [==============================] - 0s 169us/sample - loss: 0.5013 - y1_output_loss: 0.1483 - y2_output_loss: 0.3556 - y1_output_root_mean_squared_error: 0.3867 - y2_output_root_mean_squared_error: 0.5931 - val_loss: 1.3872 - val_y1_output_loss: 0.3082 - val_y2_output_loss: 1.0553 - val_y1_output_root_mean_squared_error: 0.5515 - val_y2_output_root_mean_squared_error: 1.0407
# Epoch 471/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.4372 - y1_output_loss: 0.1214 - y2_output_loss: 0.3122 - y1_output_root_mean_squared_error: 0.3499 - y2_output_root_mean_squared_error: 0.5610 - val_loss: 1.2336 - val_y1_output_loss: 0.3536 - val_y2_output_loss: 0.8645 - val_y1_output_root_mean_squared_error: 0.5905 - val_y2_output_root_mean_squared_error: 0.9407
# Epoch 472/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.3855 - y1_output_loss: 0.1156 - y2_output_loss: 0.2707 - y1_output_root_mean_squared_error: 0.3395 - y2_output_root_mean_squared_error: 0.5199 - val_loss: 1.1851 - val_y1_output_loss: 0.3668 - val_y2_output_loss: 0.8077 - val_y1_output_root_mean_squared_error: 0.5957 - val_y2_output_root_mean_squared_error: 0.9112
# Epoch 473/500
# 614/614 [==============================] - 0s 185us/sample - loss: 0.7754 - y1_output_loss: 0.1927 - y2_output_loss: 0.5769 - y1_output_root_mean_squared_error: 0.4409 - y2_output_root_mean_squared_error: 0.7623 - val_loss: 1.1372 - val_y1_output_loss: 0.2550 - val_y2_output_loss: 0.8507 - val_y1_output_root_mean_squared_error: 0.5060 - val_y2_output_root_mean_squared_error: 0.9387
# Epoch 474/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3966 - y1_output_loss: 0.1214 - y2_output_loss: 0.2722 - y1_output_root_mean_squared_error: 0.3495 - y2_output_root_mean_squared_error: 0.5239 - val_loss: 1.5289 - val_y1_output_loss: 0.3176 - val_y2_output_loss: 1.1727 - val_y1_output_root_mean_squared_error: 0.5723 - val_y2_output_root_mean_squared_error: 1.0960
# Epoch 475/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.8755 - y1_output_loss: 0.1885 - y2_output_loss: 0.6802 - y1_output_root_mean_squared_error: 0.4359 - y2_output_root_mean_squared_error: 0.8279 - val_loss: 1.0940 - val_y1_output_loss: 0.2714 - val_y2_output_loss: 0.7950 - val_y1_output_root_mean_squared_error: 0.5222 - val_y2_output_root_mean_squared_error: 0.9063
# Epoch 476/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.4286 - y1_output_loss: 0.1225 - y2_output_loss: 0.3065 - y1_output_root_mean_squared_error: 0.3466 - y2_output_root_mean_squared_error: 0.5554 - val_loss: 1.2541 - val_y1_output_loss: 0.4333 - val_y2_output_loss: 0.8259 - val_y1_output_root_mean_squared_error: 0.6426 - val_y2_output_root_mean_squared_error: 0.9172
# Epoch 477/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4977 - y1_output_loss: 0.1422 - y2_output_loss: 0.3524 - y1_output_root_mean_squared_error: 0.3777 - y2_output_root_mean_squared_error: 0.5959 - val_loss: 1.0101 - val_y1_output_loss: 0.2333 - val_y2_output_loss: 0.7622 - val_y1_output_root_mean_squared_error: 0.4787 - val_y2_output_root_mean_squared_error: 0.8837
# Epoch 478/500
# 614/614 [==============================] - 0s 185us/sample - loss: 0.3911 - y1_output_loss: 0.1208 - y2_output_loss: 0.2709 - y1_output_root_mean_squared_error: 0.3469 - y2_output_root_mean_squared_error: 0.5204 - val_loss: 1.0685 - val_y1_output_loss: 0.2362 - val_y2_output_loss: 0.8093 - val_y1_output_root_mean_squared_error: 0.4861 - val_y2_output_root_mean_squared_error: 0.9122
# Epoch 479/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4254 - y1_output_loss: 0.1173 - y2_output_loss: 0.3072 - y1_output_root_mean_squared_error: 0.3411 - y2_output_root_mean_squared_error: 0.5559 - val_loss: 1.4416 - val_y1_output_loss: 0.4611 - val_y2_output_loss: 0.9381 - val_y1_output_root_mean_squared_error: 0.6890 - val_y2_output_root_mean_squared_error: 0.9833
# Epoch 480/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4118 - y1_output_loss: 0.1003 - y2_output_loss: 0.3097 - y1_output_root_mean_squared_error: 0.3174 - y2_output_root_mean_squared_error: 0.5577 - val_loss: 1.4169 - val_y1_output_loss: 0.2668 - val_y2_output_loss: 1.1068 - val_y1_output_root_mean_squared_error: 0.5242 - val_y2_output_root_mean_squared_error: 1.0687
# Epoch 481/500
# 614/614 [==============================] - 0s 169us/sample - loss: 0.4563 - y1_output_loss: 0.1322 - y2_output_loss: 0.3225 - y1_output_root_mean_squared_error: 0.3630 - y2_output_root_mean_squared_error: 0.5697 - val_loss: 0.9555 - val_y1_output_loss: 0.2188 - val_y2_output_loss: 0.7072 - val_y1_output_root_mean_squared_error: 0.4727 - val_y2_output_root_mean_squared_error: 0.8556
# Epoch 482/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3756 - y1_output_loss: 0.1080 - y2_output_loss: 0.2665 - y1_output_root_mean_squared_error: 0.3289 - y2_output_root_mean_squared_error: 0.5171 - val_loss: 1.1915 - val_y1_output_loss: 0.2988 - val_y2_output_loss: 0.8874 - val_y1_output_root_mean_squared_error: 0.5389 - val_y2_output_root_mean_squared_error: 0.9493
# Epoch 483/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.3858 - y1_output_loss: 0.1116 - y2_output_loss: 0.2714 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.5232 - val_loss: 0.9447 - val_y1_output_loss: 0.2440 - val_y2_output_loss: 0.6869 - val_y1_output_root_mean_squared_error: 0.4872 - val_y2_output_root_mean_squared_error: 0.8410
# Epoch 484/500
# 614/614 [==============================] - 0s 180us/sample - loss: 0.6844 - y1_output_loss: 0.1690 - y2_output_loss: 0.5184 - y1_output_root_mean_squared_error: 0.4087 - y2_output_root_mean_squared_error: 0.7193 - val_loss: 3.3249 - val_y1_output_loss: 0.8601 - val_y2_output_loss: 2.4071 - val_y1_output_root_mean_squared_error: 0.9344 - val_y2_output_root_mean_squared_error: 1.5658
# Epoch 485/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.5467 - y1_output_loss: 0.1501 - y2_output_loss: 0.3927 - y1_output_root_mean_squared_error: 0.3880 - y2_output_root_mean_squared_error: 0.6294 - val_loss: 1.2221 - val_y1_output_loss: 0.4103 - val_y2_output_loss: 0.8091 - val_y1_output_root_mean_squared_error: 0.6291 - val_y2_output_root_mean_squared_error: 0.9090
# Epoch 486/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4175 - y1_output_loss: 0.1228 - y2_output_loss: 0.2917 - y1_output_root_mean_squared_error: 0.3515 - y2_output_root_mean_squared_error: 0.5421 - val_loss: 0.9939 - val_y1_output_loss: 0.2340 - val_y2_output_loss: 0.7411 - val_y1_output_root_mean_squared_error: 0.4798 - val_y2_output_root_mean_squared_error: 0.8739
# Epoch 487/500
# 614/614 [==============================] - 0s 167us/sample - loss: 0.4133 - y1_output_loss: 0.1119 - y2_output_loss: 0.3007 - y1_output_root_mean_squared_error: 0.3354 - y2_output_root_mean_squared_error: 0.5485 - val_loss: 0.9123 - val_y1_output_loss: 0.1994 - val_y2_output_loss: 0.6892 - val_y1_output_root_mean_squared_error: 0.4496 - val_y2_output_root_mean_squared_error: 0.8427
# Epoch 488/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3811 - y1_output_loss: 0.1076 - y2_output_loss: 0.2757 - y1_output_root_mean_squared_error: 0.3282 - y2_output_root_mean_squared_error: 0.5229 - val_loss: 1.2617 - val_y1_output_loss: 0.2979 - val_y2_output_loss: 0.9460 - val_y1_output_root_mean_squared_error: 0.5368 - val_y2_output_root_mean_squared_error: 0.9867
# Epoch 489/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.4209 - y1_output_loss: 0.1184 - y2_output_loss: 0.3037 - y1_output_root_mean_squared_error: 0.3449 - y2_output_root_mean_squared_error: 0.5495 - val_loss: 1.8344 - val_y1_output_loss: 0.2620 - val_y2_output_loss: 1.5183 - val_y1_output_root_mean_squared_error: 0.5145 - val_y2_output_root_mean_squared_error: 1.2529
# Epoch 490/500
# 614/614 [==============================] - 0s 171us/sample - loss: 0.5604 - y1_output_loss: 0.1435 - y2_output_loss: 0.4147 - y1_output_root_mean_squared_error: 0.3792 - y2_output_root_mean_squared_error: 0.6455 - val_loss: 1.0975 - val_y1_output_loss: 0.2528 - val_y2_output_loss: 0.8161 - val_y1_output_root_mean_squared_error: 0.5120 - val_y2_output_root_mean_squared_error: 0.9139
# Epoch 491/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4111 - y1_output_loss: 0.1106 - y2_output_loss: 0.3017 - y1_output_root_mean_squared_error: 0.3317 - y2_output_root_mean_squared_error: 0.5487 - val_loss: 1.7947 - val_y1_output_loss: 0.5771 - val_y2_output_loss: 1.2092 - val_y1_output_root_mean_squared_error: 0.7641 - val_y2_output_root_mean_squared_error: 1.1004
# Epoch 492/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3581 - y1_output_loss: 0.1098 - y2_output_loss: 0.2526 - y1_output_root_mean_squared_error: 0.3269 - y2_output_root_mean_squared_error: 0.5012 - val_loss: 4.4078 - val_y1_output_loss: 1.2047 - val_y2_output_loss: 3.1916 - val_y1_output_root_mean_squared_error: 1.0958 - val_y2_output_root_mean_squared_error: 1.7908
# Epoch 493/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.4853 - y1_output_loss: 0.1340 - y2_output_loss: 0.3493 - y1_output_root_mean_squared_error: 0.3663 - y2_output_root_mean_squared_error: 0.5926 - val_loss: 1.4089 - val_y1_output_loss: 0.2224 - val_y2_output_loss: 1.1483 - val_y1_output_root_mean_squared_error: 0.4699 - val_y2_output_root_mean_squared_error: 1.0900
# Epoch 494/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4402 - y1_output_loss: 0.1160 - y2_output_loss: 0.3207 - y1_output_root_mean_squared_error: 0.3421 - y2_output_root_mean_squared_error: 0.5685 - val_loss: 1.0146 - val_y1_output_loss: 0.2222 - val_y2_output_loss: 0.7682 - val_y1_output_root_mean_squared_error: 0.4713 - val_y2_output_root_mean_squared_error: 0.8902
# Epoch 495/500
# 614/614 [==============================] - 0s 174us/sample - loss: 0.4767 - y1_output_loss: 0.1253 - y2_output_loss: 0.3484 - y1_output_root_mean_squared_error: 0.3547 - y2_output_root_mean_squared_error: 0.5923 - val_loss: 1.0468 - val_y1_output_loss: 0.2399 - val_y2_output_loss: 0.7763 - val_y1_output_root_mean_squared_error: 0.4934 - val_y2_output_root_mean_squared_error: 0.8963
# Epoch 496/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4302 - y1_output_loss: 0.1160 - y2_output_loss: 0.3135 - y1_output_root_mean_squared_error: 0.3385 - y2_output_root_mean_squared_error: 0.5618 - val_loss: 1.0473 - val_y1_output_loss: 0.2470 - val_y2_output_loss: 0.7753 - val_y1_output_root_mean_squared_error: 0.4966 - val_y2_output_root_mean_squared_error: 0.8948
# Epoch 497/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.3655 - y1_output_loss: 0.1104 - y2_output_loss: 0.2565 - y1_output_root_mean_squared_error: 0.3331 - y2_output_root_mean_squared_error: 0.5045 - val_loss: 2.4091 - val_y1_output_loss: 0.3356 - val_y2_output_loss: 2.0029 - val_y1_output_root_mean_squared_error: 0.5900 - val_y2_output_root_mean_squared_error: 1.4356
# Epoch 498/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3643 - y1_output_loss: 0.1057 - y2_output_loss: 0.2571 - y1_output_root_mean_squared_error: 0.3247 - y2_output_root_mean_squared_error: 0.5088 - val_loss: 0.9505 - val_y1_output_loss: 0.2266 - val_y2_output_loss: 0.6973 - val_y1_output_root_mean_squared_error: 0.4805 - val_y2_output_root_mean_squared_error: 0.8483
# Epoch 499/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.8096 - y1_output_loss: 0.1948 - y2_output_loss: 0.6124 - y1_output_root_mean_squared_error: 0.4417 - y2_output_root_mean_squared_error: 0.7839 - val_loss: 1.7268 - val_y1_output_loss: 0.2395 - val_y2_output_loss: 1.4362 - val_y1_output_root_mean_squared_error: 0.4871 - val_y2_output_root_mean_squared_error: 1.2205
# Epoch 500/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4652 - y1_output_loss: 0.1240 - y2_output_loss: 0.3379 - y1_output_root_mean_squared_error: 0.3531 - y2_output_root_mean_squared_error: 0.5835 - val_loss: 0.9787 - val_y1_output_loss: 0.2581 - val_y2_output_loss: 0.7061 - val_y1_output_root_mean_squared_error: 0.5050 - val_y2_output_root_mean_squared_error: 0.8506

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 43us/sample - loss: 0.9787 - y1_output_loss: 0.2541 - y2_output_loss: 0.7149 - y1_output_root_mean_squared_error: 0.5050 - y2_output_root_mean_squared_error: 0.8506
# Loss = 0.9786631271436617, Y1_loss = 0.2541261315345764, Y1_mse = 0.5050405859947205, Y2_loss = 0.7148522138595581, Y2_mse = 0.850645124912262

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
